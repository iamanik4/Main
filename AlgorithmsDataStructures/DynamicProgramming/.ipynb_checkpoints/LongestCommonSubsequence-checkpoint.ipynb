# %% [markdown]
# ### Problem Statement
# Given to strings, S1 and S2, and their lengths, l1 and l2,find the Longest Common Sequence which occurs between them

# %%
#Using recursion
def longestCommSub(S1,S2,l1,l2):
    if l1==0 or l2==0:
        return 0
    if S1[l1-1]==S2[l2-1]:
        return 1+longestCommSub(S1,S2,l1-1,l2-1)
    else:
        return max(longestCommSub(S1,S2,l1,l2-1),longestCommSub(S1,S2,l1-1,l2))

# %%
S1 = 'abcdefghijklmnopqr'
S2 = 'bdfhjlnprabcde'
longestCommSub(S1,S2,len(S1),len(S2))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-f97d0072bf85> in <module>()
#       1 S1 = 'abcdefghijklmnopqr'
#       2 S2 = 'bdfhjlnprabcde'
# ----> 3 longestCommSub(S1,S2,len(S1),len(S2))
#
# <ipython-input-2-b73924eadb56> in longestCommSub(S1, S2, l1, l2)
#       6         return 1+longestCommSub(S1,S2,l1-1,l2-1)
#       7     else:
# ----> 8         return max(longestCommSub(S1,S2,l1,l2-1),longestCommSub(S1,S2,l1-1,l2))
#
# <ipython-input-2-b73924eadb56> in longestCommSub(S1, S2, l1, l2)
#       6         return 1+longestCommSub(S1,S2,l1-1,l2-1)
#       7     else:
# ----> 8         return max(longestCommSub(S1,S2,l1,l2-1),longestCommSub(S1,S2,l1-1,l2))
#
# <ipython-input-2-b73924eadb56> in longestCommSub(S1, S2, l1, l2)
#       6         return 1+longestCommSub(S1,S2,l1-1,l2-1)
#       7     else:
# ----> 8         return max(longestCommSub(S1,S2,l1,l2-1),longestCommSub(S1,S2,l1-1,l2))
#
# <ipython-input-2-b73924eadb56> in longestCommSub(S1, S2, l1, l2)
#       6         return 1+longestCommSub(S1,S2,l1-1,l2-1)
#       7     else:
# ----> 8         return max(longestCommSub(S1,S2,l1,l2-1),longestCommSub(S1,S2,l1-1,l2))
#
# <ipython-input-2-b73924eadb56> in longestCommSub(S1, S2, l1, l2)
#       6         return 1+longestCommSub(S1,S2,l1-1,l2-1)
#       7     else:
# ----> 8         return max(longestCommSub(S1,S2,l1,l2-1),longestCommSub(S1,S2,l1-1,l2))
#
# <ipython-input-2-b73924eadb56> in longestCommSub(S1, S2, l1, l2)
#       6         return 1+longestCommSub(S1,S2,l1-1,l2-1)
#       7     else:
# ----> 8         return max(longestCommSub(S1,S2,l1,l2-1),longestCommSub(S1,S2,l1-1,l2))
#
# <ipython-input-2-b73924eadb56> in longestCommSub(S1, S2, l1, l2)
#       6         return 1+longestCommSub(S1,S2,l1-1,l2-1)
#       7     else:
# ----> 8         return max(longestCommSub(S1,S2,l1,l2-1),longestCommSub(S1,S2,l1-1,l2))
#
# <ipython-input-2-b73924eadb56> in longestCommSub(S1, S2, l1, l2)
#       6         return 1+longestCommSub(S1,S2,l1-1,l2-1)
#       7     else:
# ----> 8         return max(longestCommSub(S1,S2,l1,l2-1),longestCommSub(S1,S2,l1-1,l2))
#
# <ipython-input-2-b73924eadb56> in longestCommSub(S1, S2, l1, l2)
#       6         return 1+longestCommSub(S1,S2,l1-1,l2-1)
#       7     else:
# ----> 8         return max(longestCommSub(S1,S2,l1,l2-1),longestCommSub(S1,S2,l1-1,l2))
#
# <ipython-input-2-b73924eadb56> in longestCommSub(S1, S2, l1, l2)
#       6         return 1+longestCommSub(S1,S2,l1-1,l2-1)
#       7     else:
# ----> 8         return max(longestCommSub(S1,S2,l1,l2-1),longestCommSub(S1,S2,l1-1,l2))
#
# <ipython-input-2-b73924eadb56> in longestCommSub(S1, S2, l1, l2)
#       6         return 1+longestCommSub(S1,S2,l1-1,l2-1)
#       7     else:
# ----> 8         return max(longestCommSub(S1,S2,l1,l2-1),longestCommSub(S1,S2,l1-1,l2))
#
# <ipython-input-2-b73924eadb56> in longestCommSub(S1, S2, l1, l2)
#       6         return 1+longestCommSub(S1,S2,l1-1,l2-1)
#       7     else:
# ----> 8         return max(longestCommSub(S1,S2,l1,l2-1),longestCommSub(S1,S2,l1-1,l2))
#
# <ipython-input-2-b73924eadb56> in longestCommSub(S1, S2, l1, l2)
#       6         return 1+longestCommSub(S1,S2,l1-1,l2-1)
#       7     else:
# ----> 8         return max(longestCommSub(S1,S2,l1,l2-1),longestCommSub(S1,S2,l1-1,l2))
#
# <ipython-input-2-b73924eadb56> in longestCommSub(S1, S2, l1, l2)
#       6         return 1+longestCommSub(S1,S2,l1-1,l2-1)
#       7     else:
# ----> 8         return max(longestCommSub(S1,S2,l1,l2-1),longestCommSub(S1,S2,l1-1,l2))
#
# <ipython-input-2-b73924eadb56> in longestCommSub(S1, S2, l1, l2)
#       6         return 1+longestCommSub(S1,S2,l1-1,l2-1)
#       7     else:
# ----> 8         return max(longestCommSub(S1,S2,l1,l2-1),longestCommSub(S1,S2,l1-1,l2))
#
# <ipython-input-2-b73924eadb56> in longestCommSub(S1, S2, l1, l2)
#       6         return 1+longestCommSub(S1,S2,l1-1,l2-1)
#       7     else:
# ----> 8         return max(longestCommSub(S1,S2,l1,l2-1),longestCommSub(S1,S2,l1-1,l2))
#
# <ipython-input-2-b73924eadb56> in longestCommSub(S1, S2, l1, l2)
#       6         return 1+longestCommSub(S1,S2,l1-1,l2-1)
#       7     else:
# ----> 8         return max(longestCommSub(S1,S2,l1,l2-1),longestCommSub(S1,S2,l1-1,l2))
#
# <ipython-input-2-b73924eadb56> in longestCommSub(S1, S2, l1, l2)
#       6         return 1+longestCommSub(S1,S2,l1-1,l2-1)
#       7     else:
# ----> 8         return max(longestCommSub(S1,S2,l1,l2-1),longestCommSub(S1,S2,l1-1,l2))
#
# <ipython-input-2-b73924eadb56> in longestCommSub(S1, S2, l1, l2)
#       6         return 1+longestCommSub(S1,S2,l1-1,l2-1)
#       7     else:
# ----> 8         return max(longestCommSub(S1,S2,l1,l2-1),longestCommSub(S1,S2,l1-1,l2))
#
# <ipython-input-2-b73924eadb56> in longestCommSub(S1, S2, l1, l2)
#       6         return 1+longestCommSub(S1,S2,l1-1,l2-1)
#       7     else:
# ----> 8         return max(longestCommSub(S1,S2,l1,l2-1),longestCommSub(S1,S2,l1-1,l2))
#
# <ipython-input-2-b73924eadb56> in longestCommSub(S1, S2, l1, l2)
#       6         return 1+longestCommSub(S1,S2,l1-1,l2-1)
#       7     else:
# ----> 8         return max(longestCommSub(S1,S2,l1,l2-1),longestCommSub(S1,S2,l1-1,l2))
#
# <ipython-input-2-b73924eadb56> in longestCommSub(S1, S2, l1, l2)
#       6         return 1+longestCommSub(S1,S2,l1-1,l2-1)
#       7     else:
# ----> 8         return max(longestCommSub(S1,S2,l1,l2-1),longestCommSub(S1,S2,l1-1,l2))
#
# <ipython-input-2-b73924eadb56> in longestCommSub(S1, S2, l1, l2)
#       6         return 1+longestCommSub(S1,S2,l1-1,l2-1)
#       7     else:
# ----> 8         return max(longestCommSub(S1,S2,l1,l2-1),longestCommSub(S1,S2,l1-1,l2))
#
# <ipython-input-2-b73924eadb56> in longestCommSub(S1, S2, l1, l2)
#       4         return 0
#       5     if S1[l1-1]==S2[l2-1]:
# ----> 6         return 1+longestCommSub(S1,S2,l1-1,l2-1)
#       7     else:
#       8         return max(longestCommSub(S1,S2,l1,l2-1),longestCommSub(S1,S2,l1-1,l2))
#
# <ipython-input-2-b73924eadb56> in longestCommSub(S1, S2, l1, l2)
#       6         return 1+longestCommSub(S1,S2,l1-1,l2-1)
#       7     else:
# ----> 8         return max(longestCommSub(S1,S2,l1,l2-1),longestCommSub(S1,S2,l1-1,l2))
#
# <ipython-input-2-b73924eadb56> in longestCommSub(S1, S2, l1, l2)
#       3     if l1==0 or l2==0:
#       4         return 0
# ----> 5     if S1[l1-1]==S2[l2-1]:
#       6         return 1+longestCommSub(S1,S2,l1-1,l2-1)
#       7     else:
#
# KeyboardInterrupt:
